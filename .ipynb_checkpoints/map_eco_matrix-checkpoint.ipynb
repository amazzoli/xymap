# %%
from xymap import XYMap
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Matrix import

# %%
mat = np.loadtxt('eco_matrix.dat')
# Removing the rows and the columns of only zeros
mat = mat[mat.sum(axis=1)>0]
mat = mat[:,mat.sum(axis=0)>0]

# %% [markdown]
# ## Running the algorithm

# %% [markdown]
# ### Definition and parameter setting

# %%
# Algorithm initialization and default parameter setting
alg = XYMap(mat)

# Current parameters. See documentation for more info
print(alg.params)
# Out:
# {'delta_conv': 1e-08, 't_max': 1000, 'low_bound': 1e-30, 'print_info': True}

# %%
# Parameters can be changed by specifying them in the algorithm contructor..
alg = XYMap(mat, delta_conv=10**(-5))

# ..or modifying directly the dictionary
alg.params['t_max'] = 500

print(alg.params)
# Out:
# {'delta_conv': 1e-05, 't_max': 500, 'low_bound': 1e-30, 'print_info': True}

# %% [markdown]
# ### Execution

# %%
# Exponent of the map
gamma = -1 # This case recover the fitness-complexity map

# Layer of the score computation: 0 for the x score of the nodes associated to the matrix rows,
# 1 for the y score of the columns.
axis = 0

alg.run(axis, gamma)
# Out:
# Convergence in 46 time steps.

# %% [markdown]
# ## Getting the result

# %% [markdown]
# ### Plotting the trajectories

# %%
# The function of the algorithm class plots the trajectories colored accodring to the node degree
fig, ax = alg.plot_traj(axis)
# Additional features of the plot can be added acting on the returned ax
ax.set_title('Score trajectories', fontsize=14)
# Out:
# Text(0.5,1,'Score trajectories')

# %% [markdown]
# ### Printing the ranking and the final scores

# %%
# Ranking of the matrix idexes
print(alg.x_ranking)

# Final scores
print(alg.x_scores)

# The trajectories are stored in a matrix where each column is the score of a given node 
# (indexes that correspond to the original matrix indexes) and each row is the set of scores
# at a given time.
print(alg.x_traj[-1]) # The last row is the list of the final scores and correspond to alg.x_scores
print(alg.x_traj[ :, alg.x_ranking[0] ]) # Trajectory of the largest x_score
# Out:
# [ 66 712 298 ... 856 674 932]
# [6.91938023e-01 3.99343039e-03 4.96374265e-03 ... 5.37704472e+00
#  3.39916951e+00 2.12925289e+00]
# [6.91938023e-01 3.99343039e-03 4.96374265e-03 ... 5.37704472e+00
#  3.39916951e+00 2.12925289e+00]
# [ 1.         11.33232169 11.71193973 11.72790955 11.69478269 11.65987479
#  11.6325212  11.61292178 11.59933835 11.59002753 11.58364925 11.5792585
#  11.57621114 11.57407393 11.57255654 11.5714642  11.57066582 11.57007267
#  11.56962435 11.56927945 11.56900934 11.56879405 11.56861953 11.56847579
#  11.56835564 11.56825385 11.56816657 11.56809092 11.56802473 11.56796633
#  11.56791444 11.56786803 11.56782631 11.56778861 11.56775442 11.56772329
#  11.56769486 11.56766883 11.56764493 11.56762295 11.56760271 11.56758402
#  11.56756676 11.56755079 11.567536   11.5675223  11.5675096 ]

# %%
plt.figure(figsize=(6,6))
plt.title('Gamma: {}, EA: {:1.3f}'.format(g, ea))
plt.imshow(mat[fc_alg.x_ranking].T[fc_alg.inverse_y_ranking[::-1]].T, cmap='gray_r', aspect='auto')
plt.savefig('plots/eco_matrix_{}.png'.format(g), dpi=300)

# %%
print(alg.params)
# Out:
# {'delta_conv': 1e-08, 't_max': 1000, 'low_bound': 1e-30, 'print_info': True}

# %% [markdown]
# ## Extinction area scanning

# %%
gammas = np.linspace(-2,1,100)
area_rows = fc_alg.scan_ext_areas(0, gammas)
area_cols = fc_alg.scan_ext_areas(1, gammas)
# Out:
# Last computed gamma: -1.9393939393939394
# /home/andrea/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:32: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims)
# Last computed gamma: 1.0696969696969697666

# %%
plt.xlabel('Map exponent', fontsize=14)
plt.ylabel('Extinction area', fontsize=14)

plt.plot(gammas, area_rows)
plt.plot(gammas, area_cols)
#plt.savefig('eco12_ext_area.svg')

# %% [markdown]
# ## Phase transition

# %%
gammas = np.linspace(0,3,)
stat_r = fc_alg.scan_stat(0, gammas)
stat_c = fc_alg.scan_stat(1, gammas)
# Out:
# Last computed gamma: -1.0452525252525259
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-4c9cd1d5f13e> in <module>
#       1 gammas = np.linspace(-1.15,-0.98,100)
# ----> 2 stat_r = fc_alg.scan_stat(0, gammas)
#       3 stat_c = fc_alg.scan_stat(1, gammas)
#
# ~/Dropbox/Research/Scaling_laws/Fitness&Complexity/updated_script/fitcomp.py in scan_stat(self, axis, gamma_list)
#     317         self.params['print_info'] = False
#     318         for g in gamma_list:
# --> 319             self.run(g, axis)
#     320             frac_stat.append(self.trajectory_stat(axis)[0]/tot_n)
#     321             if verbose:
#
# ~/Dropbox/Research/Scaling_laws/Fitness&Complexity/updated_script/fitcomp.py in run(self, gamma, axis)
#     105
#     106             s_new, o_new = self._one_step(gamma, axis, traj_score[-1],
# --> 107                                            traj_opp_score[-1], neighbours, d)
#     108
#     109             s_new, o_new = self._one_step(gamma, axis, s_new, o_new,
#
# ~/Dropbox/Research/Scaling_laws/Fitness&Complexity/updated_script/fitcomp.py in _one_step(self, gamma, axis, scores, opp_scores, neighbours, d)
#     167         s_new = _np.array([])
#     168         for i in range(d[axis]):
# --> 169             s_new = _np.append(s_new, _np.take(s_opp_exp, neighbours[axis][i]).sum())
#     170
#     171         # Computing the opposite score
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py in take(a, indices, axis, out, mode)
#     157            [5, 7]])
#     158     """
# --> 159     return _wrapfunc(a, 'take', indices, axis=axis, out=out, mode=mode)
#     160
#     161
#
# KeyboardInterrupt:

# %%
plt.xlabel('Map exponent', fontsize=14)
plt.ylabel('Frac. of positive scores', fontsize=14)

plt.plot(gammas, stat_r)
plt.plot(gammas, stat_c)
#plt.savefig('eco12_transition_fine.svg')

# %%
ind=39
print(stat_r[ind])
print(gammas[ind])
# Out:
# 0.5986590038314177
# -1.116683417085427

# %% [markdown]
# ## Find extinction area maximum

# %%
from scipy.optimize import fmin

axis = 0
fc_alg.set_params(eps=10**(-5))
fc_alg.find_best_area(0, -1, exp_step_min=0.002)
# Out:
# Convergence in 54 time steps.
# -1 0.29123605229548966
# Convergence in 15 time steps.
# -0.85 0.2771034986892519
# Convergence in 23 time steps.
# -0.9249999999999999 0.2824998319553673
# Convergence in 54 time steps.
# -0.9999999999999999 0.29123605229548966
# Convergence in 369 time steps.
# -1.075 0.3079396887813403
# Convergence in 79 time steps.
# -1.15 0.35241270081333603
# Convergence in 28 time steps.
# -1.2249999999999999 0.348058244269678
# Convergence in 39 time steps.
# -1.1874999999999998 0.3502029138939302
# Convergence in 79 time steps.
# -1.1499999999999997 0.35241270081333603
# Convergence in 306 time steps.
# -1.1124999999999996 0.32579022988505746
# Convergence in 165 time steps.
# -1.1312499999999996 0.3534860859044162
# Convergence in 79 time steps.
# -1.1499999999999997 0.35241270081333603
# Convergence in 107 time steps.
# -1.1406249999999998 0.3530008570276265
# Convergence in 165 time steps.
# -1.1312499999999999 0.3534860859044162
# Convergence in 327 time steps.
# -1.121875 0.3540238287289104
# Convergence in 306 time steps.
# -1.1125 0.32579022988505746
# Convergence in 754 time steps.
# -1.1171875 0.3543137057202393
# Convergence in 327 time steps.
# -1.121875 0.3540238287289104
# Convergence in 418 time steps.
# -1.1195312499999999 0.3541141527189622
# Convergence in 754 time steps.
# -1.1171874999999998 0.3543137057202393
# Convergence in 456 time steps.
# -1.1148437499999997 0.3320519930093433
# (0.3543137057202393, -1.1171874999999998)

# %% [markdown]
# ## Score distribution

# %%
max_time=40np.zeros((len(sizes),len(alg_list)))
fc_alg = fc.FCMap(mat, eps=0, t_max=max_time, low_bound=100**(-100))

# %%
gamma = -1
fc_alg.run(gamma,0)
# Out:
# Convergence in 40 time steps.
# Warning. Stationary state not reached.

# %%
fc_alg.plot_traj(0)
plt.savefig('trajectories_{}.png'.format(gamma), dpi=200)

# %%
plt.xscale('log')
plt.yscale('log')
plt.xlabel('x-score', fontsize=14)
plt.ylabel('pdf', fontsize=14)
plt.title('Map at $\gamma$ = {}'.format(gamma), fontsize=14)
times=[5,20,30]
for t in times:
    values = fc_alg.x_traj[t]
    h=plt.hist(values, bins=np.logspace(np.log10(min(values)), np.log10(max(values)), 10), density=True, histtype='step', lw=2, label='time: {}'.format(t))

plt.legend()
plt.savefig('score_distribution_{}.png'.format(gamma), dpi=200)

# %%
np.log10(min(values))
# Out:
# -21.026868948136027
